# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(24)
# %matplotlib inline

# %%
X = np.linspace(-100,100,1000)
y = X**2 + 6*X + 9
plt.plot(X,y)
plt.xlabel("w1")
plt.ylabel("J(w1)")
plt.xticks([], [])
plt.yticks([], [])
plt.show()
